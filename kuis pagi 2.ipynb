# %%
# kuis 1 bilangan ganjil dan genap
x = int(input('Masukkan x: '))
print('x adalah bilangan', 'genap' if (x % 2 == 0) else 'ganjil')
# Out:
# Masukkan x: 1
# x adalah bilangan ganjil

# %%
# kuis aritmatika
#Penjumlahan
print(13 + 2)
apel = 7
jeruk = 9
buah = apel + jeruk #
print(buah)

# %%
#Pengurangan
hutang = 10000
bayar = 5000
sisaHutang = hutang - bayar
print("Sisa hutang Anda adalah ", sisaHutang)

# %%
# contoh if elif dan else dan mencari eror
print("hello")
something = input("enter something")
if something == "hello":
   print ("hello for you to")
elif something == ("hi"):
   print("Hii there")
else:
  print("I dont know what", something,"means")
# Out:
# hello
# enter something
# I dont know what  means
